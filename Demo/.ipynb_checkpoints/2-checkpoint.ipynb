# %%
# !pip install akshare
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ------------------- -------------------- 0.5/1.1 MB 4.8 MB/s eta 0:00:01
#    ----------------------------- ---------- 0.8/1.1 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------------- 1.1/1.1 MB 2.3 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/13.7 MB ? eta -:--:--
#    - -------------------------------------- 0.5/13.7 MB 3.8 MB/s eta 0:00:04
#    --- ------------------------------------ 1.0/13.7 MB 2.7 MB/s eta 0:00:05
#    --- ------------------------------------ 1.3/13.7 MB 2.3 MB/s eta 0:00:06
#    ---- ----------------------------------- 1.6/13.7 MB 2.2 MB/s eta 0:00:06
#    ----- ---------------------------------- 1.8/13.7 MB 1.8 MB/s eta 0:00:07
#    ------ --------------------------------- 2.1/13.7 MB 1.7 MB/s eta 0:00:07
# ...

# %%
# !pip uninstall wheel
# !pip install wheel

# %%
# 加载模块
import akshare as ak

# 获取数据
stock_code = "600036"  # 股票代码，格式为 "sh" + 上证股票代码 或 "sz" + 深证股票代码
start_date = "20210101"  # 开始日期，格式为YYYYMMDD
end_date = "20210822"    # 结束日期，格式为YYYYMMDD

# 使用akshare获取股票日线数据
stock_zh_a_daily_df = ak.stock_zh_a_daily(symbol=stock_code, start_date=start_date, end_date=end_date)

# 打印数据
print(stock_zh_a_daily_df)

# %%
#查看数据内容
# 前面字段为 date，open，high，close，low，volume
print(data["record"][0])

# %%
# 封装函数
from datetime import datetime

from vnpy.trader.constant import Exchange, Interval
from vnpy.trader.object import BarData
from vnpy.trader.database import DB_TZ, database_manager

def download_stock_daily_data(symbol: str, exchange: Exchange):
    """基于代码和交易所下载数据"""
    exchange_map = {
        Exchange.SSE: "sh",
        Exchange.SZSE: "sz",
